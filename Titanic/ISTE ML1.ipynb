# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv (r'C:\Users\sant0\Downloads\Titanic_ISTE.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0     3.0
# 1            2       1.0     1.0
# 2            3       1.0     3.0
# 3            4       1.0     1.0
# 4            5       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked  Unnamed: 12  Unnamed: 13  \
# 0    0.0         A/5 21171   7.2500   NaN        S          NaN          NaN
# 1    0.0          PC 17599  71.2833   C85        C          NaN          NaN
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S          NaN          NaN
# ...

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.drop(axis=1,columns='Unnamed: 12',inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0     3.0
# 1            2       1.0     1.0
# 2            3       1.0     3.0
# 3            4       1.0     1.0
# 4            5       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked  Unnamed: 13  Unnamed: 14  \
# 0    0.0         A/5 21171   7.2500   NaN        S          NaN          NaN
# 1    0.0          PC 17599  71.2833   C85        C          NaN          NaN
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S          NaN          NaN
# ...

# %%
df.drop(axis=1,columns='Unnamed: 13',inplace=True)
df.drop(axis=1,columns='Unnamed: 14',inplace=True)#All of these were blank columns
df.drop(axis=1,columns='Unnamed: 15',inplace=True)
df.drop(axis=1,columns='Unnamed: 16',inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0     3.0
# 1            2       1.0     1.0
# 2            3       1.0     3.0
# 3            4       1.0     1.0
# 4            5       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked  Unnamed: 17
# 0    0.0         A/5 21171   7.2500   NaN        S          NaN
# 1    0.0          PC 17599  71.2833   C85        C          NaN
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S          NaN
# ...

# %%
df.drop(axis=1,columns='Unnamed: 17',inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0     3.0
# 1            2       1.0     1.0
# 2            3       1.0     3.0
# 3            4       1.0     1.0
# 4            5       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0    0.0         A/5 21171   7.2500   NaN        S
# 1    0.0          PC 17599  71.2833   C85        C
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3    0.0            113803  53.1000  C123        S
# 4    0.0            373450   8.0500   NaN        S

# %%
df.drop(axis=1,columns='Unnamed: 17',inplace=True)
# Out:
# <AxesSubplot:>

# %%
df.drop(axis=1,columns='Cabin',inplace=True)#Too much missing data

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0     3.0
# 1            2       1.0     1.0
# 2            3       1.0     3.0
# 3            4       1.0     1.0
# 4            5       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Embarked
# 0    0.0         A/5 21171   7.2500        S
# 1    0.0          PC 17599  71.2833        C
# 2    0.0  STON/O2. 3101282   7.9250        S
# 3    0.0            113803  53.1000        S
# 4    0.0            373450   8.0500        S

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df["Age"] = df["Age"].replace(np.NaN, df["Age"].mean())#It was numerically continuos 
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
import category_encoders as ce

# %%
column_1=df["Age"]
column_2=df["Survived"]
correlation = column_2. corr(column_1)
print(correlation)
# Out:
# -0.07110074768439575

# %%
column_3=df["Fare"]
correlation = column_3. corr(column_1)
print(correlation)
# Out:
# 0.0906711799866977

# %%
correlation = column_2. corr(column_3) 
print(correlation)
# Out:
# 0.2590131520302958

# %%
CrosstabResult=pd.crosstab(index=df['Age'],columns=df['Survived'])
print(CrosstabResult)
from scipy.stats import chi2_contingency
ChiSqResult = chi2_contingency(CrosstabResult)
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])
# Out:
# Survived  0.0  1.0
# Age
# 0.42        0    1
# 0.67        0    1
# 0.75        0    2
# 0.83        0    2
# 0.92        0    1
# ...       ...  ...
# 70.00       2    0
# 70.50       1    0
# 71.00       2    0
# 74.00       1    0
# 80.00       0    1
#
# [89 rows x 2 columns]
# The P-Value of the ChiSq Test is: 0.03306503026009295

# %%
CrosstabResult1=pd.crosstab(index=df['Fare'],columns=df['Survived'])
print(CrosstabResult1)
ChiSqResult1 = chi2_contingency(CrosstabResult1)
print('The P-Value of the ChiSq Test is:', ChiSqResult1[1])
# Out:
# Survived  0.0  1.0
# Fare
# 0.0000     14    1
# 4.0125      1    0
# 5.0000      1    0
# 6.2375      1    0
# 6.4375      1    0
# ...       ...  ...
# 227.5250    1    3
# 247.5208    1    1
# 262.3750    0    2
# 263.0000    2    2
# 512.3292    0    3
#
# [248 rows x 2 columns]
# The P-Value of the ChiSq Test is: 8.966050015695972e-12

# %%
dummies = pd.get_dummies(df.Embarked)

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0     3.0
# 1              2       1.0     1.0
# 2              3       1.0     3.0
# 3              4       1.0     1.0
# 4              5       0.0     3.0
# ..           ...       ...     ...
# 886          887       0.0     2.0
# 887          888       1.0     1.0
# 888          889       0.0     3.0
# 889          890       1.0     1.0
# 890          891       0.0     3.0
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
dummies1 = pd.get_dummies(df.Sex)

# %%
final1 = pd.concat([merged,dummies1],axis='columns')
final1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0     3.0
# 1              2       1.0     1.0
# 2              3       1.0     3.0
# 3              4       1.0     1.0
# 4              5       0.0     3.0
# ..           ...       ...     ...
# 886          887       0.0     2.0
# 887          888       1.0     1.0
# 888          889       0.0     3.0
# 889          890       1.0     1.0
# 890          891       0.0     3.0
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
final1.drop(axis=1,columns='Embarked',inplace=True)
final1.drop(axis=1,columns='Sex',inplace=True)

# %%
final1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0     3.0
# 1              2       1.0     1.0
# 2              3       1.0     3.0
# 3              4       1.0     1.0
# 4              5       0.0     3.0
# ..           ...       ...     ...
# 886          887       0.0     2.0
# 887          888       1.0     1.0
# 888          889       0.0     3.0
# 889          890       1.0     1.0
# 890          891       0.0     3.0
#
#                                                   Name        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  22.000000    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000    1.0
# 2                               Heikkinen, Miss. Laina  26.000000    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000    1.0
# 4                             Allen, Mr. William Henry  35.000000    0.0
# ..                                                 ...        ...    ...
# ...
